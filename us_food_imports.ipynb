# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
food_import_sources = pd.read_csv('C:/Users/Ashley/workspace/foodpact2/to_use/usda_food_imports_sources.csv')

# %%
food_import_sources.head()
# Out:
#      Country      1999      2000       2001       2002       2003       2004  \
# 0     Mexico  5,421.30  5,833.20   5,943.90   6,162.80   7,023.50   7,993.10
# 1     Canada  9,001.50  9,853.50  10,991.90  11,558.50  11,607.20  12,732.90
# 2      China     979.1  1,119.90   1,232.50   1,590.00   2,111.40   2,463.80
# 3  France(*)  1,980.70  1,866.80   1,836.70   2,109.10   2,492.30   2,578.50
# 4   Italy(*)  1,450.70  1,571.40   1,586.90   1,825.60   2,128.30   2,346.30
#
#         2005       2006       2007    ...           2009       2010  \
# 0   9,106.60  10,274.30  11,138.90    ...      12,210.90  14,427.90
# 1  13,665.90  14,794.70  16,410.80    ...      15,699.40  17,375.60
# 2   2,850.40   3,660.20   4,283.90    ...       4,203.00   4,854.10
# 3   2,797.50   3,164.80   3,588.60    ...       2,893.30   3,146.90
# 4   2,641.10   2,862.20   3,096.70    ...       2,939.90   3,041.10
#
#         2011       2012       2013       2014       2015       2016  \
# ...

# %%
## fig = plt.figure(figsize=(6,6), dpi=100)
## ax = plt.subplot(111)
df = pd.DataFrame(food_import_sources, columns=['Country','avg'])
## df.Data.plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=270, fontsize=17)

fig1, ax1 = plt.subplots()
ax1.pie(df, labels = 'labels', autopct='%1.1f%%', startangle=270, fontsize=17)
ax1.axis('equal')
plt.show()
### plt.figure(figsize=(16,8))
### ax = plt.subplot(120, aspect='equal')
### df.plot(kind='pie',y='avg', autopct='%1.1f%%', labels=df['Country'], legend=False, fontsize=12)
## ax.set_xticklabels(food_water_use['Crop Category'], rotation=25, fontsize=12)
## plt.yscale('log')
## plt.xlabel('Crop Category')
## plt.ylabel('Water Footprint in Metric Tons')
## plt.title('Water Footprint for Global Food Categories')
## plt.legend(loc = 'upper left')
##plt.savefig('title.png')
## plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-13c5486e3445> in <module>()
#       5
#       6 fig1, ax1 = plt.subplots()
# ----> 7 ax1.pie(df, labels = 'labels', autopct='%1.1f%%', startangle=270, fontsize=17)
#       8 ax1.axis('equal')
#       9 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# TypeError: pie() got an unexpected keyword argument 'fontsize'

# %%
df = pd.DataFrame(food_import_sources, columns=['avg'])
plot = df.plot.pie(y='avg', figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-311b7ab147b0> in <module>()
#       1 df = pd.DataFrame(food_import_sources, columns=['avg'])
# ----> 2 plot = df.plot.pie(y='avg', figsize=(5, 5))
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in pie(self, y, **kwds)
#    3378
#    3379         """
# -> 3380         return self(kind='pie', y=y, **kwds)
#    3381
#    3382     def scatter(self, x, y, s=None, c=None, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...
